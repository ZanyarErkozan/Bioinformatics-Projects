# %% [markdown]
# ## <div style="margin: 0px; background-color: #444; color: #fff; padding:8px; padding-left: 10px; padding-right: 10px; border-radius: 5px;">CNG 465 • Fall 2025-2026 • <span style="margin-left: 1px; background-color: #cf441e; border-radius: 3px; padding: 2px; padding-left: 5px; padding-right: 5px; font-size: 80%;">SEMESTER PROJECT &ndash; PHASE 1 of 2</span></div>

# %% [markdown]
# <div style="border-bottom: 2px solid;"></div>

# %% [markdown]
# #### <div style="margin-left: 0px; background-color: #116; color: #fff; padding: 5px; padding-left: 10px; padding-right: 10px; border-radius: 5px; font-size: 12pt;">CHECK THAT YOUR NAME AND STUDENT ID ARE CORRECT BELOW!</div>

# %%
student_name = "Zanyar Erkozan"
student_id = "2584985"

# %% [markdown]
# <div style="border-bottom: 2px solid;"></div>

# %% [markdown]
# ## <span id="TP" style="background-color: #444; color: white; padding: 5px; padding-left: 10px; padding-right: 10px; border-radius: 5px;">SEMESTER PROJECT &ndash; PHASE 1 of 2</span><span style="margin-left: 10px; background-color: #383; color: white; padding: 5px; padding-left: 10px; padding-right: 10px; border-radius: 5px;">100 points</span><span style="margin-left: 10px; background-color: #dd6a00; color: white; padding: 5px; padding-left: 10px; padding-right: 10px; border-radius: 5px;">(Check deadline now)</span><a href="#QTOP" style="background-color: #aaa; color: white; padding: 5px; padding-bottom: 5px; border-radius: 2px; text-align: center; border-radius: 3px; margin-left: 10px; text-decoration: none;">⇡</a>

# %% [markdown]
# Your semester project involves *forensic DNA kinship testing*. You will be building a software system that will eventually enable you to conduct this type of testing.
#
# The first stage in this work will involve building *family trees* based on given relationships and conducting certain operations on those family trees.
#
# Then, after completing the second stage of the project, you will be able to conduct forensic DNA kinship testing on chosen two-person relationships using two different DNA profiling techniques, one based on DNA fragment length and the other based on sequence data.

# %% [markdown]
# #### References:
#
# - https://link.springer.com/article/10.1007/s00414-025-03605-z

# %% [markdown]
# Remaining requirements for this project are detailed below.

# %% [markdown]
# ### <span style="background-color: #444; color: white; padding: 5px; padding-left: 10px; padding-right: 10px; margin-top: 00px; margin-bottom: 10px; border-radius: 5px;">REQUIREMENTS</span>

# %% [markdown]
# #### ormation

# %% [markdown]
# - First, you shall form a team of at least three (3) and at most four members (4)
#
# - Second, you shall enter the first name/last name/student ID of each of your team members in the following Google Sheet:
#
#  > https://docs.google.com/spreadsheets/d/1gmYEVV8JpiQG9QcBqfpwbF4t2mAUroHEv4lyNrmh5qY/edit?usp=sharing
#
#  You shall use the first available tab from the left of the list of tabs. Please do not skip tabs!
#
# - You shall pick a team tab that has not been used already&mdash;There should be enough tabs for all teams.

# %% [markdown]
# #### Family Trees

# %% [markdown]
# You will be using four (4) family trees as example input to your software system. However, your code should be capable to define any family tree.

# %% [markdown]
# ##### **Family-1**

# %% [markdown]
# <div style="text-align: center;">
# <img width="800" src='......'/>
#
# </div>

# %% [markdown]
# ##### **Family-2**

# %% [markdown]
# <div style="text-align: center;">
#
# <img width="380" src='......'/>
#
# </div>

# %% [markdown]
# ##### **Family-3**

# %% [markdown]
# <div style="text-align: center;">
#
# <img width="800" src='......'/>
#
# </div>

# %% [markdown]
# ##### **Family-45**

# %% [markdown]
# <div style="text-align: center;">
#
# <img width="1300" src='......'/>
#
# </div>

# %% [markdown]
# #### Software Requirements

# %% [markdown]
# The API for this first phase of your semester project is provided below. Inspect, understand, and follow the API as provided.
#
# - You shall pay utmost attention to designing and implementing software APIs according to the specifications that will be provided to you
#
# - You shall **document** and **test** your code as you implement your classes and functions/methods
#  - Via *testing*, you shall both *validate* and *verify* that your implementation follows the specifications provided to you
#
#  <br>
#
# - You shall implement your software system in the **Python** general-purpose programming language
#
# - **YOU SHALL NOT CHANGE the names of the methods or fields provided to you as part of the project API!**
#  - You have the freedom to choose names for your own methods/functions or fields that you define separately from those defined by the API.
#
#  <br>
#
# - You shall implement a main module named `kinship`
#
# - The `kinship` module shall define a submodule named `family_tree`, whose API is provided to you below.
#
# - You shall use the sample IDs as provided. For *untyped* individuals, you may use your own naming convention, if you wish. Note that, in Phase 2, you will need to look up the *DNA profiles* of *typed* individuals from the DNA profile database.

# %% [markdown]
# #### The `family_tree` module

# %% [markdown]
# - You shall define a Python `family_tree` module to support the following *class* definitions and their associated APIs:

# %%
from dataclasses import dataclass
from typing import List, Set, Tuple, Callable

class partnership:
 """
 This class represents a partnership between a male and a female person. A 
 partnership object is then used as a node in a family tree representation.
 """
 def __init__( self, name: str=None, is_verbose: bool=False ):
 """
 Initializes a partnership node with the given name.
 
 Parameters:
 - name: A name for this relationship. This field currently does not
 have any critical importance. The primary pieces of data are the
 parents and children objects that need to be set using the APIs of this
 class!

 Fields: 
 - parents: List of parents. This value can have at most two person
 objects in it! See the definition of the partnership_pair class later.
 - children: List of children objects
 """
 self.is_verbose = is_verbose
 self.name = name
 self.parents = partnership_pair()
 self.children = []

 def __str__( self ):
 """
 MUST IMPLEMENT!
 """
 pass

 def __repr__( self ):
 """
 MUST IMPLEMENT!
 """
 pass

 def is_parent( self, individual ):
 """
 Returns whether the specified individual is either the mother or father
 in this partnership
 
 MUST IMPLEMENT!
 """
 pass

 def is_mother( self, individual ):
 """
 Returns whether the specified individual is the mother in this
 partnership
 
 MUST IMPLEMENT!
 """
 pass

 def is_father( self, individual ):
 """
 Returns whether the specified individual is the father in this
 partnership
 
 MUST IMPLEMENT!
 """
 pass

 def add_parent( self, parent ):
 """
 Adds a new parent to the list of parents in this partnership tree node
 and also adds a back reference to this partnership node from the parent.

 Following partnership back references, we can figure out with whom this
 parent is/was in a relationship, and, via those partnership nodes, we can
 figure out this person's children (potentially from different partners).
 
 MUST IMPLEMENT!
 """
 pass

 def add_parents( self, *parents ):
 """
 Both parents can be added using this more flexible API. The order of parents
 should be immaterial.
 """
 pass

 def add_child( self, child ):
 """
 Adds a new child to the list of children for this partnership node.

 By following the child back reference, we can determine whose child this
 person is, because the child back reference takes us to the partnership
 node from where this child immediately descended.
 
 MUST IMPLEMENT!
 """
 pass

 def add_children( self, *children ):
 """
 Convenient method for adding multiple children for this partnership
 
 MUST IMPLEMENT!
 """
 pass

 @staticmethod
 def traverse( start_person, start_level=0, is_verbose=True, 
 is_level_sort=False, is_level_sort_reverse=True ) -> tuple[List[visit_node], visit_node] :
 """
 Given a "start person," that is, any person in a given family tree, 
 this method returns a list of "visit nodes" that refer to all the persons 
 in this family tree. The order of the returned list is immaterial.

 The second value that is returned is the "visit node" with the lowest 
 level. However, for this project, the particular value of this second 
 return value is immaterial.
 
 Note that the start_node_level is only a relative value. 
 
 Note also that visit_node objects contain tree-level data and a 
 reference to a person object.

 - start_level indicates the level with which the start person should be
 associated during traversal.
 - is_verbose is a boolean flag that turns on/off printing of informative 
 messages
 - is_level_sort indicates whether the returned list of visit nodes 
 should be sorted according to their level value.

 BY CONVENTION, implement level values that increase as we move towards 
 ancestors and decrease as we move towards descendants.

 - is_level_sort_reverse reverses the order of the level-based sorting if 
 True.

 MUST IMPLEMENT!
 """
 #return visited_nodes, node_with_lowest_level
 pass

class person( object ):
 """
 This class represents an individual. This class does not include any 
 definitions linked to a family tree representation. A family tree will 
 have nodes named "visit nodes" defined by the visit_node class.
 """
 def __init__( self, name=None, dna_code=None, is_verbose=False, **properties ):
 """
 Parameters:
 - name: Name of this person
 - dna_code = DNA lab code given to the sample for this person
 - is_verbose: Whether informative messages are to be printed out
 - properties: A dictionary for specifying extra properties about this
 person. For example, the state of being deceased can be specified
 using this field as well as the DNA profile for a person or different
 DNA profiles for that matter (autosomal, X/Y, mtDNA).
 
 Fields:
 - child_backref = A link/reference back to the partnership node
 where this person is listed as a child. Following this link, we
 can determine which parents this child has. However, note that we
 do not link back to both parents. Instead, we link back to the
 partnership node that itself specifies the parents.
 - partnership_backrefs: A link/reference from a parent person to the
 partnership node or nodes, since a person may have been in
 partnership with multiple others
 - dna_profile: The DNA profile of this person (markers -> alleles)
 """
 self.name = name
 self.child_backref = None
 self.partnership_backrefs = []
 self.is_verbose = is_verbose
 self.properties = properties

 def __str__( self ):
 """
 MUST IMPLEMENT
 """
 pass

 def __repr__( self ): return self.__str__()

 def __eq__( self, other_person ):
 """
 If the name field of this and the other person is identical, we
 consider the two persons "equal."
 
 MUST IMPLEMENT
 """
 pass

 def __hash__( self ):
 """
 Returns a unique hash value for this person object
 """
 return hash( self.name )

 def set_property( self, name, value ):
 """
 Sets the provided property to the given value
 """
 self.properties[name] = value

 def get_property( self, name, default=None ):
 """
 Returns the value for a specified property
 """
 return self.properties.get( name, default )

 def set_properties( self, **properties ):
 """
 Sets multiple properties on this person
 """
 for cur_prop, cur_value in properties.items():
 #
 self.properties[cur_prop] = cur_value

 def print_property( self, property_name ):
 """
 Prints the value of the given property
 """
 print( f"--- {str( self )}:\n{pf( self.get_property( property_name ) )}" )

 def gender( self ):
 """
 Returns the gender of this person.
 """
 if isinstance( self, male_person ): return 'male'
 elif isinstance( self, female_person ): return 'female'
 else:
 if self.is_verbose: print( f"### WARNING: Person {self.name} is neither male nor female!" )
 return None

 def is_male( self ):
 """
 """
 return self.gender() == 'male'

 def is_female( self ):
 """
 """
 return self.gender() == 'female'

 def is_child( self ):
 """
 Returns True if the current person is a child of a specific partnership,
 since one child can only descend from a single partnership.
 """
 return not self.child_backref is None

 def is_parent_of( self, child ):
 """
 Returns True if this person is a parent of the specified child
 """
 ps = child.child_backref

 if ps and ps.is_parent( self ):
 #
 if self.is_verbose: print( f"/// {self} is one of the parents of {child}" )
 return True
 else:
 return False

 def is_parent( self ):
 """
 Returns True if the this person is a parent, that is, a person who is
 listed in at least one partnership with children. It is possible that
 a person may have partnerships, but, without children present, a person
 is not considered a parent.
 
 return len( self.partnership_backrefs ) > 0
 """
 for cur_partnership in self.partnership_backrefs:
 #
 if len( cur_partnership.children ):
 #
 return True

 return False

 def descendants( self ):
 """
 Given a top ancestor node, this method traverses all descendants of that
 ancestor. Naturally, people who may have formed partnerships with any of
 these descendants will be excluded.

 MUST IMPLEMENT
 """
 pass

 def ancestors( self ):
 """
 Returns a list of all ancestors of the provided person, starting from
 parents and moving towards more distant ancestors.

 MUST IMPLEMENT
 """
 pass

class male_person( person ):
 """
 This class defines a male person. The fact that the subclass is of type 
 male_person is the indicator of the gender.
 NOTE: The definition of this class is complete, and there should be no need 
 to add new definitions to this class!
 """
 pass

class female_person( person ):
 """
 This class defines a male person. The fact that the subclass is of type 
 female_person is the indicator of the gender.
 NOTE: The definition of this class is complete, and there should be no need 
 to add new definitions to this class!
 """
 pass

@dataclass
class partnership_pair:
 """
 This class defines a partnership pair, that is, a partnership between a
 given male and female person who formed a partnership at some point in
 time. This class only defines a mother and a father, as you can see from
 the following field definitions.
 """
 mother: person=None
 father: person=None

 pass

@dataclass( eq=True, frozen=True )
class visit_node:
 """
 This class refers to an individual represented by a person object, who is 
 part of a given family tree. This class is used during all operations on a 
 given family tree such as search or traversal.

 To represent individuals properly in a family tree, we need to use a level
 parameter that indicates at what level a given person node resides in that
 family tree.

 Of course, we can choose to represent the level of a node either in a person 
 object or do so separately as the API for this project requires--that is, we 
 opted for the latter option. Therefore, visiting a particular person node in a given 
 family tree during search or traversal should cause a "visit node" to be created 
 for each person in that family tree.
 
 VERY IMPORTANT: 
 
 1) To create hashable instances from visit nodes, we need to set the eq 
 and frozen parameters to True

 Reference: https://stackoverflow.com/questions/52390576/how-can-i-make-a-python-dataclass-hashable

 2) The definition of this class should be considered complete, and, 
 therefore, there should be no need to add extra definitions to this
 class. Yet, you are free to do so without breaking the API provided to 
 you.
 """
 person_ref: person=None
 level: int=None

#
# End of family_tree.py
#

# %% [markdown]
# For example, we could define a `search()` method for the `partnership` class as follows:

# %%
class partnership:
 """
 NOTE that this is only a partial definition to demonstrate how you may
 want to write a search method. For the complete definition, see the 
 family_tree.py file created from the above code cell.
 """
 
 @staticmethod
 def search( start_person_node: person, search_criterion: Callable=lambda p: True ):
 """
 Search for all nodes that satisfy the search criterion. Note that we
 could embed this capability in traverse(), but, since we will have to go
 through all nodes, there is no need to add any more complications there.
 """
 all_visited_nodes, _ = partnership.traverse( start_person_node )
 result = []

 for cur_visited_node in all_visited_nodes:
 #
 if search_criterion( cur_visited_node.person_ref ):
 #
 if self.is_verbose: print( f"[+] {cur_visited_node.person_ref} satisfies search criterion" )
 result.append( cur_visited_node.person_ref )

 return result

# %% [markdown]
# - The first return value from the `partnership.traverse()` method shall be a list of all nodes in the given family tree.
# - That is, given any node, named a *start node*, in a family tree, `partnership.traverse()` shall return a list of all unique *visit nodes*, each of which referring to a unique *person* node in the given family tree.

# %% [markdown]
# #### Definition of a family tree

# %% [markdown]
# - A family tree shall be defined using the following APIs defined above:
#  - `partnership()` to define each partnership
#  - Note that a person may have *multiple* partnerships
#  - `male_person()` or `female_person()` to create each individual in the family tree with a gender designation
#  - `partnership.add_parent()` or `partnership.add_parents()` to specify the parents of a given partnership
#  - `partnership.add_child()` or `partnership.add_children()` to specify the children who are born out of a given partnership
# - Keep in mind that you shall also define a variable named `start_person` that shall refer to an arbitrary person in a given family tree
# - Given the family tree for *Family-1* above, here is how the family tree could be implemented using the `kinship.family_tree` module:
#  - Each family definition should be considered as a separate module named after the family. For example, the following content could be stored in a file named `family1_config.py`

# %%
from kinship.family_tree import male_person, female_person, partnership

#-------------------------------------------------------------------------------
# FAMILY TREE
#-------------------------------------------------------------------------------
#
p1 = partnership( name='Partnership( T19_F1_XY07, T19_F1_XX04 )' )
p2 = partnership( name='Partnership( T19_F1_XY21, T19_F1_XX13 )' )
p3 = partnership( name='Partnership( T19_F1_XYU1, T19_F1_XX17 )' )
p4 = partnership( name='Partnership( T19_F1_XY06, T19_F1_xxu2 )' )
p5 = partnership( name='Partnership( T19_F1_XY15, T19_F1_XX16 )' )
p6 = partnership( name='Partnership( T19_F1_XY22, T19_F1_XX19 )' )

f1_xy07 = male_person( name="T19_F1_XY07" )
f1_xy21 = male_person( name="T19_F1_XY21" )
f1_xyu1 = male_person( name="T19_F1_XYU1", is_typed=False ) # Unknown male 1
f1_xy06 = male_person( name="T19_F1_XY06" )
f1_xy15 = male_person( name="T19_F1_XY15" )
f1_xy22 = male_person( name="T19_F1_XY22" )

f1_xx04 = female_person( name="T19_F1_XX04" )
f1_xx13 = female_person( name="T19_F1_XX13" )
f1_xx17 = female_person( name="T19_F1_XX17", is_typed=False ) # Untyped female
f1_xxu2 = female_person( name="T19_F1_XXU2", is_typed=False ) # Unknown female 1
f1_xx16 = female_person( name="T19_F1_XX16" )
f1_xx19 = female_person( name="T19_F1_XX19" )

f1_xx46 = female_person( name="T19_F1_XX46" )
f1_xx14 = female_person( name="T19_F1_XX14" )
f1_xx03 = female_person( name="T19_F1_XX03" )
f1_xx18 = female_person( name="T19_F1_XX18" )
f1_xy24 = male_person( name="T19_F1_XY24" )

p1.add_parents( f1_xy07, f1_xx04 )
p2.add_parents( f1_xy21, f1_xx13 )
p3.add_parents( f1_xyu1, f1_xx17 )
p4.add_parents( f1_xy06, f1_xxu2 )
p5.add_parents( f1_xy15, f1_xx16 )
p6.add_parents( f1_xy22, f1_xx19 )

p1.add_children( f1_xx13, f1_xx17, f1_xy06, f1_xy15 )
p2.add_children( f1_xy22 )
p3.add_children( f1_xx46 )
p4.add_children( f1_xx14, f1_xx03 )
p5.add_children( f1_xx18 )
p6.add_children( f1_xy24 )

start_person = f1_xy07 # CRITICAL

# %% [markdown]
# - Note that `start_person` shall refer to a `person` object in a given family tree and should be chosen arbitrarily.
#
# - Note also that, using `partnership.traverse()`, one shall be able to get all `person` nodes in the family tree via the `visit_node`s returned.

# %% [markdown]
# #### Extraction/Determination of family relationships (kinships
#
# - The `extract_relationship()` function shall be implemented in a Python module named `analyze_family_tree`.

# %%
#%%file analyze_family_tree.py

# %%
def extract_relationship( person_id_a: str, person_id_b: str, family_config ) -> str:
 """
 Extracts or determines the type of family relationship between the two 
 persons whose sample IDs are specified along with the family configuration,
 which defines the `start_person`.
 """
 pass

# %% [markdown]
# **Example:**
#
# Below is an example that shows how the `extract_relationship()` function may be used.

# %%
from analyze_family_tree import extract_relationship, NoSuchPersonError, IdenticalPersonError
import family1_config as family_config 
#import ipdb

tests = [
 ['T19_F1_XX16', 'T19_F1_XY24'],
 ['T19_F1_XX19', 'T19_F1_XX18'],
 ['T19_F1_XY22', 'T19_F1_XX18'],
 ['T19_F1_XY24', 'T19_F1_XX18'],
 ['T19_F1_XY24', 'T19_F1_XX18'],
 ['T19_F1_XY24', 'T19_F1_XY15'],
 ['T19_F1_XX46', 'T19_F1_XY15'],
 ['T19_F1_XX16', 'T19_F1_XX16'],
 ['T19_F1_XX16', 'T19_F1_XY24'], # UNRELATED individuals
 ['T19_F1_XX16', 'T19_F1_XY99'], # There is no XY99
 ['T19_F1_XX99', 'T19_F1_XY99'], # There is no XY99
 ['T19_F1_XX99', 'T19_F1_XY88'], # There is no XY88 and XY99
]

relationships = []

for cur_person_a, cur_person_b in tests:
 #
 try:
 cur_relationship = extract_relationship( cur_person_a, cur_person_b, family_config )

 except NoSuchPersonError as nspe:
 #
 print( f"### WARNING: One or more of the specified persons do not exist in the family tree! {str( nspe )}" )
 cur_relationship = None

 except IdenticalPersonError as ipe:
 #
 print( f"### WARNING: The same person specified: {str( ipe )}" )
 cur_relationship = None

 print( f"/// {cur_person_a}, {cur_person_b} -> {cur_relationship}" )

 relationships.append( [cur_person_a, cur_person_b, cur_relationship] )

 #ipdb.set_trace()

print( f"--- Relationships: {relationships}" )

# %% [markdown]
# should print out

# %% [raw]
# --- Relationships: [['T19_F1_XX16', 'T19_F1_XY24', 'unrelated'], ['T19_F1_XX19', 'T19_F1_XX18', 'unrelated'], ['T19_F1_XY22', 'T19_F1_XX18', 'first_cousins'], ['T19_F1_XY24', 'T19_F1_XX18', 'first_cousins_once_removed'], ['T19_F1_XY24', 'T19_F1_XX18', 'first_cousins_once_removed'], ['T19_F1_XY24', 'T19_F1_XY15', 'greatuncle_greatnephew'], ['T19_F1_XX46', 'T19_F1_XY15', 'uncle_niece'], ['T19_F1_XX16', 'T19_F1_XX16', None], ['T19_F1_XX16', 'T19_F1_XY24', 'unrelated'], ['T19_F1_XX16', 'T19_F1_XY99', None], ['T19_F1_XX99', 'T19_F1_XY99', None], ['T19_F1_XX99', 'T19_F1_XY88', None]]

# %% [markdown]
# Note that, as specified further below, there may be sample IDs that are nonexistent! There also may be cases where an identical sample ID is specified as argument to `extract_relationship()` twice.
#
# Since the test code catches and handles such exceptional cases by setting the relationship category to `None`, the above relationship list includes `None` for such relationships. That is, you should take note that the `None` values in these kinds of cases are <u>not</u> returned by `extract_relationship()` but simply set by the above test code for demonstration only.

# %% [markdown]
# #### Family relation types to be supported by your system

# %% [markdown]
# The list of family relationships (kinships) your system shall support is provided below.
#
# That is, your `extract_relationship()` function shall return the following symbols *(strings)* (all lowercase):
#
# - `father_daughter`
# - `father_son`
# - `mother_daughter`
# - `mother_son`
# - `full_siblings`
# - `first_cousins`
# - `first_cousins_once_removed`
# - `first_cousins_twice_removed`
# - `second_cousins`
# - `second_cousins_once_removed`
# - `second_cousins_twice_removed`
# - `aunt_niece`
# - `aunt_nephew`
# - `uncle_niece`
# - `uncle_nephew`
# - `grandfather_granddaughter`
# - `grandfather_grandson`
# - `grandmother_granddaughter`
# - `grandmother_grandson`
# - `greataunt_greatniece`
# - `greataunt_greatnephew`
# - `greatuncle_greatniece`
# - `greatuncle_greatnephew`
# - `greatgrandmother_greatgranddaughter`
# - `greatgrandmother_greatgrandson`
# - `greatgrandfather_greatgranddaughter`
# - `greatgrandfather_greatgrandson`
# - `greatgrandmother_greatgranddaughter`
# - `greatgrandmother_greatgrandson`
# - `greatgrandfather_greatgranddaughter`
# - `greatgrandfather_greatgrandson`

# %% [markdown]
# ##### Additional relationship categories
#
# - If the two individuals specified are *unrelated*, then `extract_relationship()` shall return the symbol/string `unrelated` (all lowercase).
#
# - If the relationship in question is <u>not</u> one of those specified above, then `extract_relationship()` shall return the symbol/string `unrecognized` (all lowercase)

# %% [markdown]
# ##### Additional cases to be handled
#
# - If a sample ID is <u>not</u> even in a family tree, then your `extract_relationship()` shall raise an `NoSuchPersonError`.
#
# - If the sample IDs provided to `extract_relationship()` are identical belonging to an individual in the provided family tree, `extract_relationship()` shall raise an `IdenticalPersonError`.

# %% [markdown]
# #### Report

# %% [markdown]
# - You shall prepare a detailed *report* of your work highlighting how you designed and implemented your solution for both problems and the results you obtained
# - Your report shall
#  - identify your team according to the team tab in the Google Sheet above and also specify your team members with their official name and student ID
#  - describe the **contribution** of each team member to the project
#  - visually depict your software architecture and the data flow between different modules/submodules in your systems
#  - validate and verify your work by *testing* your systems thoroughly
#  - describe the results of your work
#  - describe the working parts of your software in case you are unable to fully comply with the provided specifications
#  - In such cases, you shall describe, at length, what works in your software and what does <u>not</u> with specific inputs
#  - include a special section that clearly describes how to build, (possibly install), and run your system!
# - You shall <u>not</u> use any AI or similar tool to write and/or correct your report
#  - **An "AI" content above 15% shall be severely penalized!**
#  - Your report document and source code submissions shall be checked for *plagiarism*

# %% [markdown]
# <div style="border-bottom: 2px solid;"></div>

# %% [markdown]
# **The instructor reserves the right to add further clarification/details to this document in such a way that will not modify the original project requirements.**

# %% [markdown]
# <div style="border-bottom: 2px solid;"></div>

# %% [markdown]
# - __All _Rules of Academic Conduct_ apply__. Any sort of *plagiarism* will result in an __FF__ grade for the course. Your case will also be submitted to the Faculty Disciplinary Committee for further evaluation and disciplinary action. You can refer to books and web pages for help, but you are __not__ allowed to consult anyone online. Any sort of collaboraton with anyone anywhere is considered cheating.

# %% [markdown]
# <div style="border-bottom: 2px solid;"></div>

# %% [markdown]
# #### Grading breakdown

# %% [markdown]
# | Type of Work | Points |
# |--------------|--------|
# | Report| 30 points |
# | Correct implementation (Testing & Validation) | 60 points |
# | Overall organization of all project files/overall presentation of work| 10 points |

# %% [markdown]
# #### Submission

# %% [markdown]
# - You shall upload the following documents using separate links on ODTUClass&mdash;Please follow the additional instructions provided there:
#
#  1. Your report for Turnitin checking&mdash;an upload link will be provided to you at a later date
#  2. A copy of this notebook with your name and student ID correctly filled in
#  - **IMPORTANT:** You must upload this file as it is required for you to receive your grade via the NBGRADER system
#  - Since you need <u>not</u> provide any content in this file, you may upload this file even now!
#  3. Your source code and detailed instructions about how to build and run your testing framework
#  - **Failure to provide detailed instructions will be heavily penalized!**
#
# - No late submissions will be accepted!
#
# **Best of luck!**

# %% [markdown]
# <div style="border-bottom: 2px solid;"></div>

# %% [markdown]
# <span style="display: inline-block; width: 100%; background-color: #dd6a00; color: white; padding: 5px; padding-left: 10px; padding-right: 10px; border-radius: 5px; text-align: center; font-weight: bold;">END OF SEMESTER PROJECT &ndash; PHASE 1 of 2</span>
